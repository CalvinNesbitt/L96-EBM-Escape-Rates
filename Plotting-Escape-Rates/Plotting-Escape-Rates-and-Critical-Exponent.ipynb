# %%
from input_output import *
import numpy.random as rm

# %%
SB_transient_lifetimes = get_SB_transient_lifetime_data()
W_transient_lifetimes = get_W_transient_lifetime_data()

# %% [markdown]
# # Looking at Transient Lifetimes

# %% [markdown]
# ## Mean Transient lifetimes as a function of S

# %%
for transient_lifetime in [W_transient_lifetimes, SB_transient_lifetimes]:
    transient_lifetime.S_vs_mean_lifetime_plot()

# %% [markdown]
# ## Example Histograms

# %%
for transient_lifetime in [W_transient_lifetimes, SB_transient_lifetimes]:
    transient_lifetime[rm.randint(10)].histogram_plot()

# %% [markdown]
# # Escape Rate Fits

# %%
for transient_lifetime in [W_transient_lifetimes, SB_transient_lifetimes]:
    transient_lifetime[rm.randint(10)].escape_rate_fit_plot()
# Out:
# /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Escape-Rates/Transient-Lifetime-Classes/escapeRateCalculations.py:61: RuntimeWarning: divide by zero encountered in log
#   ax.scatter( ns, np.nan_to_num(np.log(scs), neginf=0), **kwargs)
# /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Escape-Rates/Transient-Lifetime-Classes/escapeRateCalculations.py:61: RuntimeWarning: divide by zero encountered in log
#   ax.scatter( ns, np.nan_to_num(np.log(scs), neginf=0), **kwargs)

# %% [markdown]
# ## Escape Rate Scaling - Computing Critical Exponent

# %%
W_transient_lifetimes.scaling_law_fit_plot(c='orange')
SB_transient_lifetimes.scaling_law_fit_plot(c='b')
    
fax = init_2d_fax()
W_transient_lifetimes.scaling_law_fit_plot(c='orange', fax=fax)
SB_transient_lifetimes.scaling_law_fit_plot(c='b', fax=fax)
# Out:
# (<Figure size 481.883x297.82 with 1 Axes>,
#  <AxesSubplot:title={'center':'Critical Exponent fit'}, xlabel='$|S - S_{crit}|$', ylabel='$\\kappa$'>)
